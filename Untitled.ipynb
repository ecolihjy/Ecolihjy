# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import mne

# %%
sample_data_raw_file = "D:/UserCode/hjy/dynamic stop/FFT-test/EEG_DATA4.cnt"
raw = mne.io.read_raw_cnt(sample_data_raw_file, verbose=False)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19476\854993446.py:2: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = mne.io.read_raw_cnt(sample_data_raw_file, verbose=False)

# %%
events = mne.events_from_annotations(raw)
epochs = mne.Epochs(raw, events[0], baseline=(0, 0.5))
epochs.plot()
# Out:
# Used Annotations descriptions: ['1']
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 701 original time points ...
# 0 bad epochs dropped
# Using matplotlib as 2D backend.
# Loading data for 20 events and 701 original time points ...
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw.plot(n_channels=60)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
epochs.plot(n_channels=50 ,picks="P3")
# Out:
# Loading data for 20 events and 701 original time points ...
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
